# %%
import pandas as pd
df = pd.read_csv('/Users/belle/Desktop/analysis/data_analysis/tt/collected@07-09-11/trending@07-07-16/TikTok_trending@07-07-16_collected@07-09-11/Texas Patrick Abbott Cyclone_TikTok_trending@07-07-16_collected@07-09-11.csv')
df
# Out:
#      position                   id  diggCount  shareCount  commentCount  \
# 0           1  7388967662015073566       17.0         1.0           1.0
# 1           2  7389215900525776171       13.0         0.0           0.0
# 2           0  7364537586267933998      111.0        22.0          14.0
# 3           4  7389142861616483630        6.0         0.0           0.0
# 4           3  7149214867331943726     1863.0        27.0         634.0
# ..        ...                  ...        ...         ...           ...
# 235       235  7297738128226389290    13800.0       152.0         137.0
# 236       236  7159250977382501678    29100.0        72.0         904.0
# 237       238  7222884019787156778     2909.0        99.0          50.0
# 238       237  7158558648938269998     7500.0        68.0         104.0
# 239       239  7251319832140909867     4381.0       100.0          35.0
#
#      playCount  collectCount  repostCount           createTime  isAd  ...  \
# ...

# %%
df.rename(columns={'diggCount':'likes'},inplace=True)
df['platform'] = 'tiktok'
df
# Out:
#      position                   id    likes  shareCount  commentCount  \
# 0           1  7388967662015073566     17.0         1.0           1.0
# 1           2  7389215900525776171     13.0         0.0           0.0
# 2           0  7364537586267933998    111.0        22.0          14.0
# 3           4  7389142861616483630      6.0         0.0           0.0
# 4           3  7149214867331943726   1863.0        27.0         634.0
# ..        ...                  ...      ...         ...           ...
# 235       235  7297738128226389290  13800.0       152.0         137.0
# 236       236  7159250977382501678  29100.0        72.0         904.0
# 237       238  7222884019787156778   2909.0        99.0          50.0
# 238       237  7158558648938269998   7500.0        68.0         104.0
# 239       239  7251319832140909867   4381.0       100.0          35.0
#
#      playCount  collectCount  repostCount           createTime  isAd  ...  \
# ...

# %%
df_fb = pd.read_csv('/Users/belle/Desktop/analysis/data_analysis/fb/collected@07-02-14/trending@06-28-13/Facebook_trending@06-28-13_collected@07-02-14/SCOTUS Social Media Biden_Facebook_trending@06-28-13_collected@07-02-14.csv')
df_fb['']
# Out:
#      type                                                url  \
# 0    post  https://www.facebook.com/story.php?story_fbid=...
# 1   watch  https://www.facebook.com/HillTVLive/videos/wat...
# 2    post  https://www.facebook.com/story.php?story_fbid=...
# 3    post  https://www.facebook.com/story.php?story_fbid=...
# 4    post  https://www.facebook.com/story.php?story_fbid=...
# 5    post  https://www.facebook.com/story.php?story_fbid=...
# 6    post  https://www.facebook.com/story.php?story_fbid=...
# 7   video  https://www.facebook.com/HillTVLive/videos/hun...
# 8    post  https://www.facebook.com/story.php?story_fbid=...
# 9    post  https://www.facebook.com/story.php?story_fbid=...
# 10   post  https://www.facebook.com/story.php?story_fbid=...
# 11   post  https://www.facebook.com/story.php?story_fbid=...
# 12   post  https://www.facebook.com/story.php?story_fbid=...
# 13   post  https://www.facebook.com/story.php?story_fbid=...
# ...
